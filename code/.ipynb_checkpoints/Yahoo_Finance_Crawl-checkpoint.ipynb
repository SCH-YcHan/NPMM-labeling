# %%
import yfinance as yf
import pandas as pd

# %%
#2021/02/04 NASDAQ, NYSE SYMBOL Load
NASDAQ_sb = pd.read_csv("../data/NASDAQ_MC10B_210203.csv")

# %%
#Sort by Market Cap 100
NASDAQ100 = NASDAQ_sb.sort_values("Market Cap", ascending=False)[:100]
NASDAQ100
# Out:
#     Symbol                                               Name Last Sale  \
# 1     AAPL                            Apple Inc. Common Stock   $134.99
# 128   MSFT                 Microsoft Corporation Common Stock   $239.51
# 17    AMZN                       Amazon.com Inc. Common Stock  $3380.00
# 86    GOOG                Alphabet Inc. Class C Capital Stock  $1927.51
# 87   GOOGL                 Alphabet Inc. Class A Common Stock  $1919.12
# ..     ...                                                ...       ...
# 93    IBKR  Interactive Brokers Group Inc. Class A Common ...    $68.33
# 173   RPRX        Royalty Pharma plc Class A Ordinary Shares     $46.65
# 220     ZS                          Zscaler Inc. Common Stock   $216.71
# 181   SPLK                           Splunk Inc. Common Stock   $175.09
# 9     AFRM          Affirm Holdings Inc. Class A Common Stock   $113.00
#
#      Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# 1          0.85   0.634%  2.340368e+12  United States    1980.0  82910342
# 128       -0.14  -0.058%  1.806436e+12  United States    1986.0  25846038
# 17        37.12    1.11%  1.695919e+12  United States    1997.0   7014736
# 86        26.16   1.376%  1.303818e+12  United States    2004.0   2246080
# 87        26.05   1.376%  1.298143e+12  United States       NaN   3283750
# ..          ...      ...           ...            ...       ...       ...
# 93         2.81   4.289%  2.927514e+10  United States    2019.0   1626277
# 173       -0.08  -0.171%  2.916746e+10  United States    2020.0   1380163
# 220       12.24   5.986%  2.908072e+10  United States    2018.0   1891720
# 181        3.46   2.016%  2.831570e+10  United States    2012.0   1968128
# 9          5.39   5.009%  2.743039e+10  United States    2021.0   1864349
#
#                 Sector                                        Industry
# 1           Technology                          Computer Manufacturing
# 128         Technology         Computer Software: Prepackaged Software
# 17   Consumer Services                  Catalog/Specialty Distribution
# 86          Technology  Computer Software: Programming Data Processing
# 87          Technology  Computer Software: Programming Data Processing
# ..                 ...                                             ...
# 93             Finance              Investment Bankers/Brokers/Service
# 173        Health Care                           Major Pharmaceuticals
# 220         Technology                                    EDP Services
# 181         Technology         Computer Software: Prepackaged Software
# 9        Miscellaneous                               Business Services
#
# [100 rows x 11 columns]

# %%
NASDAQ100[(NASDAQ100["IPO Year"]<2009) | (NASDAQ100["IPO Year"].isna())]
# Out:
#     Symbol                                               Name Last Sale  \
# 1     AAPL                            Apple Inc. Common Stock   $134.99
# 128   MSFT                 Microsoft Corporation Common Stock   $239.51
# 17    AMZN                       Amazon.com Inc. Common Stock  $3380.00
# 86    GOOG                Alphabet Inc. Class C Capital Stock  $1927.51
# 87   GOOGL                 Alphabet Inc. Class A Common Stock  $1919.12
# ..     ...                                                ...       ...
# 175   SBAC  SBA Communications Corporation Class A Common ...   $281.90
# 199  VIACA                ViacomCBS Inc. Class A Common Stock    $50.30
# 198   VIAC                ViacomCBS Inc. Class B Common Stock    $50.26
# 183   SWKS               Skyworks Solutions Inc. Common Stock   $185.49
# 177   SGEN                           Seagen Inc. Common Stock   $166.05
#
#      Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# 1          0.85   0.634%  2.340368e+12  United States    1980.0  82910342
# 128       -0.14  -0.058%  1.806436e+12  United States    1986.0  25846038
# 17        37.12    1.11%  1.695919e+12  United States    1997.0   7014736
# 86        26.16   1.376%  1.303818e+12  United States    2004.0   2246080
# 87        26.05   1.376%  1.298143e+12  United States       NaN   3283750
# ..          ...      ...           ...            ...       ...       ...
# 175        3.63   1.304%  3.130302e+10  United States    1999.0   1106146
# 199       -2.08  -3.971%  3.104748e+10  United States       NaN     92860
# 198       -2.07  -3.956%  3.102279e+10  United States       NaN  17681233
# 183       -0.30  -0.161%  3.058730e+10  United States       NaN   3750982
# 177        3.19   1.959%  2.972239e+10  United States    2001.0    965833
#
#                 Sector                                           Industry
# 1           Technology                             Computer Manufacturing
# 128         Technology            Computer Software: Prepackaged Software
# 17   Consumer Services                     Catalog/Specialty Distribution
# 86          Technology     Computer Software: Programming Data Processing
# 87          Technology     Computer Software: Programming Data Processing
# ..                 ...                                                ...
# 175  Consumer Services                      Real Estate Investment Trusts
# 199  Consumer Services                                       Broadcasting
# 198  Consumer Services                                       Broadcasting
# 183         Technology                                     Semiconductors
# 177        Health Care  Biotechnology: Biological Products (No Diagnos...
#
# [80 rows x 11 columns]

# %%
NASDAQ100_Price = NASDAQ100_Price.dropna(axis=1)

# %%
def tuple_join(tuple_var):
    return(tuple_var[1]+" "+tuple_var[0])

def multicol_join_sort(multicol_df):
    multicol_df.columns = list(map(tuple_join, multicol_df.columns))
    multicol_df = multicol_df[sorted(multicol_df.columns.tolist())]
    multicol_df.reset_index(inplace=True)
    return(multicol_df)

# %%
NASDAQ100_Price = multicol_join_sort(NASDAQ100_Price)
NASDAQ100_Price
# Out:
#            Date  AAPL Adj Close  AAPL Close   AAPL High    AAPL Low  \
# 0    2009-01-02        2.795912    3.241071    3.251429    3.041429
# 1    2009-01-05        2.913911    3.377857    3.435000    3.311071
# 2    2009-01-06        2.865849    3.322143    3.470357    3.299643
# 3    2009-01-07        2.803922    3.250357    3.303571    3.223571
# 4    2009-01-08        2.855989    3.310714    3.326786    3.215714
# ...         ...             ...         ...         ...         ...
# 3038 2021-01-28      137.089996  137.089996  141.990005  136.699997
# 3039 2021-01-29      131.960007  131.960007  136.740005  130.210007
# 3040 2021-02-01      134.139999  134.139999  135.380005  130.929993
# 3041 2021-02-02      134.990005  134.990005  136.309998  134.610001
# 3042 2021-02-03      133.940002  133.940002  135.740005  133.610001
#
#        AAPL Open  AAPL Volume  ADBE Adj Close  ADBE Close   ADBE High  ...  \
# 0       3.067143    746015200       23.020000   23.020000   23.100000  ...
# 1       3.327500   1181608400       23.129999   23.129999   23.309999  ...
# 2       3.426786   1289310400       24.219999   24.219999   24.450001  ...
# 3       3.278929    753048800       24.230000   24.230000   24.809999  ...
# 4       3.229643    673500800       24.290001   24.290001   24.379999  ...
# ...          ...          ...             ...         ...         ...  ...
# 3038  139.520004    142621100      465.670013  465.670013  475.019989  ...
# 3039  135.830002    177180600      458.769989  458.769989  465.000000  ...
# 3040  133.750000    106239800      470.000000  470.000000  474.799988  ...
# 3041  135.729996     83305400      484.929993  484.929993  487.369995  ...
# 3042  135.759995     82762729      481.920013  481.920013  488.839996  ...
#
#        XEL High    XEL Low   XEL Open  XEL Volume  XLNX Adj Close  XLNX Close  \
# 0     18.950001  18.490000  18.590000     2018300       13.925655   18.360001
# 1     18.969999  18.440001  18.820000     2908200       13.834635   18.240000
# 2     19.000000  18.320000  18.740000     3009200       14.115276   18.610001
# 3     18.400000  18.110001  18.299999     2523000       13.569165   17.889999
# 4     18.469999  18.160000  18.160000     2929700       12.894120   17.000000
# ...         ...        ...        ...         ...             ...         ...
# 3038  65.440002  61.990002  63.180000     2995600      133.570007  133.570007
# 3039  64.599998  62.919998  63.180000     2540500      130.570007  130.570007
# 3040  64.930000  63.349998  64.150002     2715400      135.309998  135.309998
# 3041  65.160004  63.610001  63.880001     2002400      137.309998  137.309998
# 3042  64.189499  63.105000  64.089996     1982622      135.389999  135.389999
#
#        XLNX High    XLNX Low   XLNX Open  XLNX Volume
# 0      18.450001   17.580000   17.680000      6026000
# 1      18.879999   18.110001   18.110001      5936600
# 2      18.799999   18.190001   18.389999      6199300
# 3      18.469999   17.760000   18.260000      6296000
# 4      17.700001   16.639999   17.650000     14456300
# ...          ...         ...         ...          ...
# 3038  137.190002  133.029999  137.050003      2457500
# 3039  134.710007  129.570007  132.710007      2751700
# 3040  135.639999  130.309998  132.440002      2826800
# 3041  137.910004  134.699997  136.699997      4443800
# 3042  138.490005  135.110001  137.479996      2965455
#
# [3043 rows x 433 columns]

# %%
NASDAQ100_Price.to_csv("../data/NASDAQ100.csv", index=False)

# %%
NASDAQ_2009 = list(set(list(map(lambda x: x.split()[0],NASDAQ100_Price.columns.tolist()))))

# %%
NASDAQ100_2009 = NASDAQ100[NASDAQ100["Symbol"].isin(NASDAQ_2009)]
NASDAQ100_2009
# Out:
#     Symbol                                               Name Last Sale  \
# 1     AAPL                            Apple Inc. Common Stock   $134.99
# 128   MSFT                 Microsoft Corporation Common Stock   $239.51
# 17    AMZN                       Amazon.com Inc. Common Stock  $3380.00
# 86    GOOG                Alphabet Inc. Class C Capital Stock  $1927.51
# 87   GOOGL                 Alphabet Inc. Class A Common Stock  $1919.12
# ..     ...                                                ...       ...
# 153   PCAR                           PACCAR Inc. Common Stock    $91.89
# 175   SBAC  SBA Communications Corporation Class A Common ...   $281.90
# 183   SWKS               Skyworks Solutions Inc. Common Stock   $185.49
# 177   SGEN                           Seagen Inc. Common Stock   $166.05
# 93    IBKR  Interactive Brokers Group Inc. Class A Common ...    $68.33
#
#      Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# 1          0.85   0.634%  2.340368e+12  United States    1980.0  82910342
# 128       -0.14  -0.058%  1.806436e+12  United States    1986.0  25846038
# 17        37.12    1.11%  1.695919e+12  United States    1997.0   7014736
# 86        26.16   1.376%  1.303818e+12  United States    2004.0   2246080
# 87        26.05   1.376%  1.298143e+12  United States       NaN   3283750
# ..          ...      ...           ...            ...       ...       ...
# 153        0.71   0.779%  3.184907e+10  United States       NaN   2042781
# 175        3.63   1.304%  3.130302e+10  United States    1999.0   1106146
# 183       -0.30  -0.161%  3.058730e+10  United States       NaN   3750982
# 177        3.19   1.959%  2.972239e+10  United States    2001.0    965833
# 93         2.81   4.289%  2.927514e+10  United States    2019.0   1626277
#
#                 Sector                                           Industry
# 1           Technology                             Computer Manufacturing
# 128         Technology            Computer Software: Prepackaged Software
# 17   Consumer Services                     Catalog/Specialty Distribution
# 86          Technology     Computer Software: Programming Data Processing
# 87          Technology     Computer Software: Programming Data Processing
# ..                 ...                                                ...
# 153      Capital Goods                                 Auto Manufacturing
# 175  Consumer Services                      Real Estate Investment Trusts
# 183         Technology                                     Semiconductors
# 177        Health Care  Biotechnology: Biological Products (No Diagnos...
# 93             Finance                 Investment Bankers/Brokers/Service
#
# [72 rows x 11 columns]

# %%
NASDAQ100_2009.to_csv("../data/NASDAQ100_2009_CUT.csv", index=False)
